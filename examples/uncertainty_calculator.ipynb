# %% [markdown]
# <a href="https://colab.research.google.com/github/FridrichMethod/UncertaintyCalculator/blob/main/examples/uncertainty_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Uncertainty Calculator
#
# > Copyright <https://github.com/FridrichMethod>.

# %%
# Install the package from GitHub
# %pip install git+https://github.com/FridrichMethod/UncertaintyCalculator.git
# Out:
# Collecting git+https://github.com/FridrichMethod/UncertaintyCalculator.git
#   Cloning https://github.com/FridrichMethod/UncertaintyCalculator.git to /private/var/folders/dn/zcv6fgb15nq7s0t324p7jw3m0000gn/T/pip-req-build-j7naywvp
#   Running command git clone --filter=blob:none --quiet https://github.com/FridrichMethod/UncertaintyCalculator.git /private/var/folders/dn/zcv6fgb15nq7s0t324p7jw3m0000gn/T/pip-req-build-j7naywvp
#   Resolved https://github.com/FridrichMethod/UncertaintyCalculator.git to commit b0c893a2431bf8ab4d8a45c2a48f4e73a2c7d47c
#   Installing build dependencies ... -
# \
# |
# /
# done
#   Getting requirements to build wheel ... -
# done
#   Preparing metadata (pyproject.toml) ... -
# done
# Requirement already satisfied: sympy in /Users/zhaoyangli/Data/repos/UncertaintyCalculator/.venv/lib/python3.12/site-packages (from uncertainty_calculator==0.1.1) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/zhaoyangli/Data/repos/UncertaintyCalculator/.venv/lib/python3.12/site-packages (from sympy->uncertainty_calculator==0.1.1) (1.3.0)
# Building wheels for collected packages: uncertainty_calculator
#   Building wheel for uncertainty_calculator (pyproject.toml) ... -
# done
#   Created wheel for uncertainty_calculator: filename=uncertainty_calculator-0.1.1-py3-none-any.whl size=11977 sha256=50ef493376da80168640647e7fdd074f27a6c02f2409d6f4e2b66a3d346fac6b
#   Stored in directory: /private/var/folders/dn/zcv6fgb15nq7s0t324p7jw3m0000gn/T/pip-ephem-wheel-cache-8sds7g73/wheels/5b/ef/24/6c08ee507c9b6512802346bd701bc6a3e79fdcdca0f276f1a4
# Successfully built uncertainty_calculator
# Installing collected packages: uncertainty_calculator
#   Attempting uninstall: uncertainty_calculator
#     Found existing installation: uncertainty_calculator 0.1.1
#     Uninstalling uncertainty_calculator-0.1.1:
#       Successfully uninstalled uncertainty_calculator-0.1.1
# Successfully installed uncertainty_calculator-0.1.1
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Input

# %%
from uncertainty_calculator import Digits, Equation, Variable

# Define equation
equation = Equation(latex_name=r"\zeta", expression=r"(K*pi*eta*u*l)/(4*pi*phi*e_0*e_r)")

# Define variables
variables = [
    Variable(name="K", value=4.0, uncertainty=0.0, latex_name="K"),
    Variable(name="eta", value=0.9358e-3, uncertainty=5.773502691896258e-05, latex_name=r"\eta"),
    Variable(name="u", value=3.68e-5, uncertainty=0.11e-5, latex_name="u"),
    Variable(name="l", value=0.2256, uncertainty=0.0019, latex_name="l"),
    Variable(name="phi", value=100.0, uncertainty=0.5773502691896257, latex_name=r"\varphi"),
    Variable(name="e_0", value=8.8541878128e-12, uncertainty=0.0, latex_name=r"\varepsilon_0"),
    Variable(
        name="e_r", value=78.7, uncertainty=0.057735026918962574, latex_name=r"\varepsilon_\text{r}"
    ),
]

# Set digits of results
digits = Digits(mu=3, sigma=3)

# Set units of results
last_unit = r"\text{V}"  # Use None if dimensionless
# last_unit = None

# Print separately or integrally
separate = False

# Insert numbers or not
insert = False

# Include equation number or not
include_equation_number = False

# %% [markdown]
# ## Run

# %%
from uncertainty_calculator import UncertaintyCalculator

calculator = UncertaintyCalculator(
    digits=digits,
    last_unit=last_unit,
    separate=separate,
    insert=insert,
    include_equation_number=include_equation_number,
)

latex_string = calculator.run(equation=equation, variables=variables)

print(latex_string)
# Out:
# \begin{equation*}
# \begin{aligned}
# \zeta&=\frac{K \eta l u}{4 \varepsilon_0 \varepsilon_\text{r} \varphi}=0.111\ \text{V}\\
# \\
# \frac{\partial \zeta }{\partial \eta }&=\frac{K l u}{4 \varepsilon_0 \varepsilon_\text{r} \varphi}=1.2 \times 10^{2}\\
# \frac{\partial \zeta }{\partial u }&=\frac{K \eta l}{4 \varepsilon_0 \varepsilon_\text{r} \varphi}=3.0 \times 10^{3}\\
# \frac{\partial \zeta }{\partial l }&=\frac{K \eta u}{4 \varepsilon_0 \varepsilon_\text{r} \varphi}=0.49\\
# \frac{\partial \zeta }{\partial \varphi }&=- \frac{K \eta l u}{4 \varepsilon_0 \varepsilon_\text{r} \varphi^{2}}=-0.0011\\
# \frac{\partial \zeta }{\partial \varepsilon_\text{r} }&=- \frac{K \eta l u}{4 \varepsilon_0 \varepsilon_\text{r}^{2} \varphi}=-0.0014\\
# \\
# \sigma_{\zeta}&=\sqrt{\left(\frac{\partial \zeta }{\partial \eta } \sigma_{\eta}\right)^2+\left(\frac{\partial \zeta }{\partial u } \sigma_{u}\right)^2+\left(\frac{\partial \zeta }{\partial l } \sigma_{l}\right)^2+\left(\frac{\partial \zeta }{\partial \varphi } \sigma_{\varphi}\right)^2+\left(\frac{\partial \zeta }{\partial \varepsilon_\text{r} } \sigma_{\varepsilon_\text{r}}\right)^2}\\
# &=\sqrt{\left(0.0069\right)^2+\left(0.0033\right)^2+\left(0.00094\right)^2+\left(-0.00064\right)^2+\left(-8.2 \times 10^{-5}\right)^2}\\
# &=0.00773\ \text{V}\\
# \\
# \zeta&=\left (0.111 \pm 0.00773 \right )\ \text{V}
# \end{aligned}
# \end{equation*}

# %% [markdown]
# ## Render

# %%
from IPython.display import Latex

Latex(latex_string)
# Out:
# \begin{equation*}
# \begin{aligned}
# \zeta&=\frac{K \eta l u}{4 \varepsilon_0 \varepsilon_\text{r} \varphi}=0.111\ \text{V}\\
# \\
# \frac{\partial \zeta }{\partial \eta }&=\frac{K l u}{4 \varepsilon_0 \varepsilon_\text{r} \varphi}=1.2 \times 10^{2}\\
# \frac{\partial \zeta }{\partial u }&=\frac{K \eta l}{4 \varepsilon_0 \varepsilon_\text{r} \varphi}=3.0 \times 10^{3}\\
# \frac{\partial \zeta }{\partial l }&=\frac{K \eta u}{4 \varepsilon_0 \varepsilon_\text{r} \varphi}=0.49\\
# \frac{\partial \zeta }{\partial \varphi }&=- \frac{K \eta l u}{4 \varepsilon_0 \varepsilon_\text{r} \varphi^{2}}=-0.0011\\
# \frac{\partial \zeta }{\partial \varepsilon_\text{r} }&=- \frac{K \eta l u}{4 \varepsilon_0 \varepsilon_\text{r}^{2} \varphi}=-0.0014\\
# \\
# \sigma_{\zeta}&=\sqrt{\left(\frac{\partial \zeta }{\partial \eta } \sigma_{\eta}\right)^2+\left(\frac{\partial \zeta }{\partial u } \sigma_{u}\right)^2+\left(\frac{\partial \zeta }{\partial l } \sigma_{l}\right)^2+\left(\frac{\partial \zeta }{\partial \varphi } \sigma_{\varphi}\right)^2+\left(\frac{\partial \zeta }{\partial \varepsilon_\text{r} } \sigma_{\varepsilon_\text{r}}\right)^2}\\
# &=\sqrt{\left(0.0069\right)^2+\left(0.0033\right)^2+\left(0.00094\right)^2+\left(-0.00064\right)^2+\left(-8.2 \times 10^{-5}\right)^2}\\
# &=0.00773\ \text{V}\\
# \\
# \zeta&=\left (0.111 \pm 0.00773 \right )\ \text{V}
# \end{aligned}
# \end{equation*}
